# %% [markdown]
# # 寫入 dataframe 到 sqlite 中

# %%
import pandas as pd
import pandas_datareader.data as web

# %%
df = web.DataReader('TSLA','yahoo','2015-01-01','2018-12-31')

# %%
import sqlite3

# %%
conn = sqlite3.connect("test.db")

# %%
df.to_sql('TSLA', conn, if_exists='append')
# Out:
# C:\Users\victor\Anaconda3\lib\site-packages\pandas\core\generic.py:2130: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
df = pd.read_sql('select * from TSLA', conn, parse_dates=['Date'])

# %%
df.sort_values('Date').head()
# Out:
#            Date        High         Low        Open       Close   Volume  \
# 0    2014-12-31  225.679993  222.250000  223.089996  222.410004  2297500
# 1007 2014-12-31  225.679993  222.250000  223.089996  222.410004  2297500
# 1    2015-01-02  223.250000  213.259995  222.869995  219.309998  4764400
# 1008 2015-01-02  223.250000  213.259995  222.869995  219.309998  4764400
# 2    2015-01-05  216.500000  207.160004  214.550003  210.089996  5368500
#
#        Adj Close
# 0     222.410004
# 1007  222.410004
# 1     219.309998
# 1008  219.309998
# 2     210.089996

# %%
df = df.set_index('Date')

# %%
df.sort_index().head()
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2014-12-31  225.679993  222.250000  223.089996  222.410004  2297500
# 2014-12-31  225.679993  222.250000  223.089996  222.410004  2297500
# 2015-01-02  223.250000  213.259995  222.869995  219.309998  4764400
# 2015-01-02  223.250000  213.259995  222.869995  219.309998  4764400
# 2015-01-05  216.500000  207.160004  214.550003  210.089996  5368500
#
#              Adj Close
# Date
# 2014-12-31  222.410004
# 2014-12-31  222.410004
# 2015-01-02  219.309998
# 2015-01-02  219.309998
# 2015-01-05  210.089996

# %%
df.drop_duplicates()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2014-12-31  225.679993  222.250000  223.089996  222.410004   2297500
# 2015-01-02  223.250000  213.259995  222.869995  219.309998   4764400
# 2015-01-05  216.500000  207.160004  214.550003  210.089996   5368500
# 2015-01-06  214.199997  204.210007  210.059998  211.279999   6261900
# 2015-01-07  214.779999  209.779999  213.350006  210.949997   2968400
# 2015-01-08  213.800003  210.009995  212.809998  210.619995   3442500
# 2015-01-09  209.979996  204.960007  208.919998  206.660004   4668300
# 2015-01-12  204.470001  199.250000  203.050003  202.210007   5950300
# 2015-01-13  207.610001  200.910004  203.320007  204.250000   4477300
# 2015-01-14  195.199997  185.000000  185.830002  192.690002  11551900
# 2015-01-15  195.750000  190.000000  194.490005  191.869995   5216500
# 2015-01-16  194.490005  189.649994  190.699997  193.070007   3603200
# ...
